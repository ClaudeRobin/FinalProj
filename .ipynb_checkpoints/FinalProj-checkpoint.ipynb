# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
dfOct = pd.read_csv("/home/claude/Documents/ProjOct.csv",encoding='utf-8', header=14)

# %%
dfSept = pd.read_csv("/home/claude/Documents/ProjSept.csv",encoding='utf-8', header=14)

# %%
dfAug = pd.read_csv("/home/claude/Documents/ProjAug.csv",encoding='utf-8', header=14)

# %%
dfAug
# Out:
#           Houston  $218,000   -6.4%    1.4%  2322    5.5%   38.1%
# 0          Humble  $200,000   -1.7%    8.1%   243   -1.2%   29.3%
# 1      Huntsville  $169,950   -2.9%   -7.1%    40   14.3%   21.2%
# 2            Katy  $253,175    1.3%    7.7%   575   -5.6%   33.4%
# 3        Kingwood  $250,000    7.8%   -3.3%    62  -15.1%   -3.1%
# 4       La Marque  $166,250   29.9%    7.6%    30   42.9%  200.0%
# 5        La Porte  $178,950   -1.7%    0.0%    38  -22.4%   18.8%
# 6     League City  $280,000   -4.8%    1.9%   165    7.1%   13.0%
# 7      Livingston  $141,750  -13.0%  -28.9%    46   27.8%   91.7%
# 8        Magnolia  $315,000    7.1%   15.6%   115   -0.9%   17.3%
# 9          Manvel  $325,000    2.0%   14.4%    47   -2.1%   88.0%
# 10  Missouri City  $259,950   -6.0%    5.1%   160    5.3%   81.8%
# 11     Montgomery  $306,999   -6.1%   -1.6%   127  -15.9%   21.0%
# 12       Pasadena  $176,500   -0.8%   15.8%    81   -2.4%   50.0%
# ...

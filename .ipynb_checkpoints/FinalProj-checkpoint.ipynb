# %% [markdown]
# # Final Project: Houston Pre/Post Flooding

# %% [markdown]
# ## import packages

# %%
import pandas as pd

# %%
import numpy as np

# %%
import sklearn  as sk
import pylab as pl
from sklearn.cluster import KMeans

from sklearn.decomposition import PCA

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## read from csv file

# %%
houserate = pd.read_csv(r'C:\\Users\\laura\\Desktop\\COMSC-4393\datadata.csv',encoding='latin1', header=0)
# Out:
#       hpi_type        hpi_flavor  frequency level  \
# 0  traditional  all-transactions  quarterly   MSA
# 1  traditional  all-transactions  quarterly   MSA
# 2  traditional  all-transactions  quarterly   MSA
# 3  traditional  all-transactions  quarterly   MSA
# 4  traditional  all-transactions  quarterly   MSA
#
#                              place_name  place_id    yr  period  index_nsa
# 0  Houston-The Woodlands-Sugar Land, TX     26420  1976       1      51.59
# 1  Houston-The Woodlands-Sugar Land, TX     26420  1976       2      58.33
# 2  Houston-The Woodlands-Sugar Land, TX     26420  1976       3      57.98
# 3  Houston-The Woodlands-Sugar Land, TX     26420  1976       4      57.80
# 4  Houston-The Woodlands-Sugar Land, TX     26420  1977       1      59.92

# %% [markdown]
# # K-means

# %%
Y = houserate[['index_nsa']]

X = houserate[['yr']]

Nc = range(1, 20)

kmeans = [KMeans(n_clusters=i) for i in Nc]

#kmeans

score = [kmeans[i].fit(Y).score(Y) for i in range(len(kmeans))]

#score

pl.plot(Nc,score)

pl.xlabel('Number of Clusters')

pl.ylabel('Score')

pl.title('Elbow Curve')

pl.show()

# %%
pca = PCA(n_components=1).fit(Y)

pca_d = pca.transform(Y)

pca_c = pca.transform(X)

kmeans=KMeans(n_clusters=3)

kmeansoutput=kmeans.fit(Y)

kmeansoutput

pl.figure('3 Cluster K-Means')

pl.scatter(pca_c[:, 0], pca_d[:, 0], c=kmeansoutput.labels_)

pl.xlabel('Dividend Yield')

pl.ylabel('Returns')

pl.title('3 Cluster K-Means')

pl.show()

# %% [markdown]
# ### Reference 1: https://www.datasciencecentral.com/profiles/blogs/python-implementing-a-k-means-algorithm-with-sklearn
